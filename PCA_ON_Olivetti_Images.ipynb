# %% [markdown]
# <a href="https://colab.research.google.com/github/tejeshbhalla/Machine-Learning-From-Scratch/blob/master/PCA_ON_Olivetti_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import files
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_olivetti_faces
import matplotlib.pyplot as plt 
from sklearn.decomposition import PCA

# %%
images=fetch_olivetti_faces()['images']

images.shape
# Out:
# (400, 64, 64)

# %%
fig1=plt.figure(figsize=(12,12))
for i in range(0,50):
  ax=fig1.add_subplot(8,8,i+1)
  ax.imshow(images[i],cmap=plt.cm.bone)
plt.show()

# %%
x=fetch_olivetti_faces()['data']
y=fetch_olivetti_faces()['target']

# %%
pca=PCA(64)
x=pca.fit_transform(x)
pca.explained_variance_ratio_
# Out:
# array([0.23812702, 0.13993965, 0.07968619, 0.04998332, 0.0360985 ,
#        0.03156944, 0.02426833, 0.02036398, 0.01958113, 0.01672122,
#        0.01595222, 0.0143698 , 0.01246742, 0.01147133, 0.01062877,
#        0.00977721, 0.00919061, 0.00815574, 0.00753875, 0.00746985,
#        0.00698578, 0.00614627, 0.00583928, 0.00569722, 0.0054619 ,
#        0.00531856, 0.00513816, 0.0049584 , 0.00457663, 0.00441181,
#        0.00401997, 0.00384179, 0.0036194 , 0.00334535, 0.00320367,
#        0.00316015, 0.00305108, 0.00298596, 0.00282007, 0.00273948,
#        0.00259532, 0.00253776, 0.00244471, 0.0023976 , 0.00230424,
#        0.0022624 , 0.00221665, 0.00219994, 0.00207666, 0.00203983,
#        0.00195709, 0.00190755, 0.00182953, 0.00178016, 0.00176316,
#        0.0016845 , 0.00164559, 0.00161351, 0.00159631, 0.00155067,
#        0.00153948, 0.00149956, 0.00147337, 0.00142558], dtype=float32)

# %%
k_factor=90
for i in range(len(pca.explained_variance_ratio_)):
  sum=pca.explained_variance_ratio_[:i].sum()
  if sum*100>k_factor:
    break
print(i)
# Out:
# 63

# %%
x.shape
# Out:
# (400, 196)

# %%
14*14
# Out:
# 196

# %%
x=pca.inverse_transform(x)
x=x.reshape(400,64,64)
fig1=plt.figure(figsize=(12,12))
for i in range(0,50):
  ax=fig1.add_subplot(8,8,i+1)
  ax.imshow(x[i],cmap=plt.cm.bone)
plt.show()
